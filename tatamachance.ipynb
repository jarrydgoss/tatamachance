# %%
import os
import pandas as pd

# %%
data = pd.read_csv(os.path.join("powerball.csv"))
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#       Draw number   Draw date  Winning Number 1  Winning Number 2  \
# 0            1424  31/08/2023                10                35
# 1            1423  24/08/2023                 8                17
# 2            1422  17/08/2023                24                12
# 3            1421  10/08/2023                11                24
# 4            1420  03/08/2023                13                 7
# ...           ...         ...               ...               ...
# 1419            5  20/06/1996                 3                15
# 1420            4  13/06/1996                25                37
# 1421            3  06/06/1996                 4                32
# 1422            2  30/05/1996                 6                 8
# 1423            1  23/05/1996                 2                 8
#
#       Winning Number 3  Winning Number 4  Winning Number 5  Winning Number 6  \
# 0                   27                32                 6              14.0
# ...

# %%
df['Draw date'] = pd.to_datetime(df['Draw date'], format='%d/%m/%Y')


#df['Draw date'] = df['Draw date'].dt.strftime('%Y%m%d')

# %%
print("\nDataFrame with cleaned and formatted date values:")
print(df)
# Out:
# DataFrame with cleaned and formatted date values:
#       Draw number  Draw date  Winning Number 1  Winning Number 2  \
# 0            1424 2023-08-31                10                35
# 1            1423 2023-08-24                 8                17
# 2            1422 2023-08-17                24                12
# 3            1421 2023-08-10                11                24
# 4            1420 2023-08-03                13                 7
# ...           ...        ...               ...               ...
# 1419            5 1996-06-20                 3                15
# 1420            4 1996-06-13                25                37
# 1421            3 1996-06-06                 4                32
# 1422            2 1996-05-30                 6                 8
# 1423            1 1996-05-23                 2                 8
#
#       Winning Number 3  Winning Number 4  Winning Number 5  Winning Number 6  \
# ...

# %%
file_path = '/workspaces/tatamachance/powerball_cleaned.csv'

df.to_csv(file_path, index=False)

# %%
df.iloc[5:, 10:]
# Out:
#       Division 1 winners  Division 1 winners in WA  Division 1 prize pool  \
# 5                    0.0                       0.0                    0.0
# 6                    0.0                       0.0                    0.0
# 7                    0.0                       0.0                    0.0
# 8                    0.0                       0.0                    0.0
# 9                    0.0                       0.0                    0.0
# ...                  ...                       ...                    ...
# 1419                 NaN                       NaN                    NaN
# 1420                 NaN                       NaN                    NaN
# 1421                 NaN                       NaN                    NaN
# 1422                 NaN                       NaN                    NaN
# 1423                 NaN                       NaN                    NaN
#
#       Division 1 amount  Division 2 winners  Division 2 winners in WA  \
# ...

# %%
df.head()
# Out:
#    Draw number  Draw date  Winning Number 1  Winning Number 2  \
# 0         1424 2023-08-31                10                35
# 1         1423 2023-08-24                 8                17
# 2         1422 2023-08-17                24                12
# 3         1421 2023-08-10                11                24
# 4         1420 2023-08-03                13                 7
#
#    Winning Number 3  Winning Number 4  Winning Number 5  Winning Number 6  \
# 0                27                32                 6              14.0
# 1                18                20                11               3.0
# 2                30                26                10              17.0
# 3                 9                23                18              16.0
# 4                18                 1                23              25.0
#
#    Winning Number 7  Powerball Number  ...  Division 7 prize pool  \
# 0              31.0                 6  ...             3010512.75
# ...
